# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Imports & data

# %%
import pandas as pd
athletes = pd.read_csv("../dataset/Olympic_Athlete_Bio.csv")
athlete_results = pd.read_csv("../dataset/Olympic_Athlete_Event_Results.csv")
countries = pd.read_csv("../dataset/Olympics_Country.csv")
games = pd.read_csv("../dataset/Olympics_Games.csv")

# %% [markdown]
# - Merge weight, height, born and sex

# %%
dataset = athlete_results.merge(athletes[['athlete_id','weight', 'height', 'born', 'sex']], on='athlete_id', how='left')
dataset
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 314902  2022 Winter Olympics          62         NED  Bobsleigh
# 314903  2022 Winter Olympics          62         SVK  Bobsleigh
# 314904  2022 Winter Olympics          62         KOR  Bobsleigh
# 314905  2022 Winter Olympics          62         JAM  Bobsleigh
# 314906  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# 1       400 metres, Men      56313                Henry Murray       64756
# 2       800 metres, Men      56338               Harvey Sutton       64808
# 3       800 metres, Men      56338                 Guy Haskins      922519
# 4       800 metres, Men      56338                Joseph Lynch       64735
# ...                 ...        ...                         ...         ...
# 314902   Monobob, Women   19019671              Karlien Sleper      148662
# 314903   Monobob, Women   19019671          Viktória Čerňanská      138683
# 314904   Monobob, Women   19019671                  Kim Yu-Ran      137542
# 314905   Monobob, Women   19019671  Jazmine Fenlator-Victorian      128682
# 314906   Monobob, Women   19019671                Lidiya Hunko      149047
#
#               pos medal  isTeamSport weight height        born     sex
# 0             DNS    na        False     na     na  1889-06-17    Male
# 1             DNS    na        False     na     na  1886-01-14    Male
# 2       3 h8 r1/2    na        False     na     na  1882-02-18    Male
# 3             DNS    na        False     na     na  1883-12-23    Male
# 4             DNS    na        False     na     na  1878-04-22    Male
# ...           ...   ...          ...    ...    ...         ...     ...
# 314902         16    na        False     na     na  1993-01-11  Female
# 314903         17    na        False     76  175.0  2002-03-29  Female
# 314904         18    na        False     78  170.0  1992-04-23  Female
# 314905         19    na        False  75-78  175.0  1985-08-29  Female
# 314906         20    na        False     na     na  1993-08-10  Female
#
# [314907 rows x 15 columns]

# %% [markdown]
# - Merge country

# %%
dataset = dataset.merge(countries[['country_noc', 'country']], on='country_noc', how='left')
dataset
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316086  2022 Winter Olympics          62         NED  Bobsleigh
# 316087  2022 Winter Olympics          62         SVK  Bobsleigh
# 316088  2022 Winter Olympics          62         KOR  Bobsleigh
# 316089  2022 Winter Olympics          62         JAM  Bobsleigh
# 316090  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# 1       400 metres, Men      56313                Henry Murray       64756
# 2       800 metres, Men      56338               Harvey Sutton       64808
# 3       800 metres, Men      56338                 Guy Haskins      922519
# 4       800 metres, Men      56338                Joseph Lynch       64735
# ...                 ...        ...                         ...         ...
# 316086   Monobob, Women   19019671              Karlien Sleper      148662
# 316087   Monobob, Women   19019671          Viktória Čerňanská      138683
# 316088   Monobob, Women   19019671                  Kim Yu-Ran      137542
# 316089   Monobob, Women   19019671  Jazmine Fenlator-Victorian      128682
# 316090   Monobob, Women   19019671                Lidiya Hunko      149047
#
#               pos medal  isTeamSport weight height        born     sex  \
# 0             DNS    na        False     na     na  1889-06-17    Male
# 1             DNS    na        False     na     na  1886-01-14    Male
# 2       3 h8 r1/2    na        False     na     na  1882-02-18    Male
# 3             DNS    na        False     na     na  1883-12-23    Male
# 4             DNS    na        False     na     na  1878-04-22    Male
# ...           ...   ...          ...    ...    ...         ...     ...
# 316086         16    na        False     na     na  1993-01-11  Female
# 316087         17    na        False     76  175.0  2002-03-29  Female
# 316088         18    na        False     78  170.0  1992-04-23  Female
# 316089         19    na        False  75-78  175.0  1985-08-29  Female
# 316090         20    na        False     na     na  1993-08-10  Female
#
#                   country
# 0             Australasia
# 1             Australasia
# 2             Australasia
# 3             Australasia
# 4             Australasia
# ...                   ...
# 316086        Netherlands
# 316087           Slovakia
# 316088  Republic of Korea
# 316089            Jamaica
# 316090            Ukraine
#
# [316091 rows x 16 columns]

# %% [markdown]
# - Merge year and city

# %%
dataset = dataset.merge(games[['edition_id', 'year', 'city']], on='edition_id', how='left')
dataset
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316086  2022 Winter Olympics          62         NED  Bobsleigh
# 316087  2022 Winter Olympics          62         SVK  Bobsleigh
# 316088  2022 Winter Olympics          62         KOR  Bobsleigh
# 316089  2022 Winter Olympics          62         JAM  Bobsleigh
# 316090  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# 1       400 metres, Men      56313                Henry Murray       64756
# 2       800 metres, Men      56338               Harvey Sutton       64808
# 3       800 metres, Men      56338                 Guy Haskins      922519
# 4       800 metres, Men      56338                Joseph Lynch       64735
# ...                 ...        ...                         ...         ...
# 316086   Monobob, Women   19019671              Karlien Sleper      148662
# 316087   Monobob, Women   19019671          Viktória Čerňanská      138683
# 316088   Monobob, Women   19019671                  Kim Yu-Ran      137542
# 316089   Monobob, Women   19019671  Jazmine Fenlator-Victorian      128682
# 316090   Monobob, Women   19019671                Lidiya Hunko      149047
#
#               pos medal  isTeamSport weight height        born     sex  \
# 0             DNS    na        False     na     na  1889-06-17    Male
# 1             DNS    na        False     na     na  1886-01-14    Male
# 2       3 h8 r1/2    na        False     na     na  1882-02-18    Male
# 3             DNS    na        False     na     na  1883-12-23    Male
# 4             DNS    na        False     na     na  1878-04-22    Male
# ...           ...   ...          ...    ...    ...         ...     ...
# 316086         16    na        False     na     na  1993-01-11  Female
# 316087         17    na        False     76  175.0  2002-03-29  Female
# 316088         18    na        False     78  170.0  1992-04-23  Female
# 316089         19    na        False  75-78  175.0  1985-08-29  Female
# 316090         20    na        False     na     na  1993-08-10  Female
#
#                   country  year     city
# 0             Australasia  1908   London
# 1             Australasia  1908   London
# 2             Australasia  1908   London
# 3             Australasia  1908   London
# 4             Australasia  1908   London
# ...                   ...   ...      ...
# 316086        Netherlands  2022  Beijing
# 316087           Slovakia  2022  Beijing
# 316088  Republic of Korea  2022  Beijing
# 316089            Jamaica  2022  Beijing
# 316090            Ukraine  2022  Beijing
#
# [316091 rows x 18 columns]

# %% [markdown]
# - Remove teamsports, keep only individual sports

# %%
dataset = dataset[dataset['isTeamSport'] == False]
dataset
# Out:
#                      edition  edition_id country_noc      sport  \
# 0       1908 Summer Olympics           5         ANZ  Athletics
# 1       1908 Summer Olympics           5         ANZ  Athletics
# 2       1908 Summer Olympics           5         ANZ  Athletics
# 3       1908 Summer Olympics           5         ANZ  Athletics
# 4       1908 Summer Olympics           5         ANZ  Athletics
# ...                      ...         ...         ...        ...
# 316086  2022 Winter Olympics          62         NED  Bobsleigh
# 316087  2022 Winter Olympics          62         SVK  Bobsleigh
# 316088  2022 Winter Olympics          62         KOR  Bobsleigh
# 316089  2022 Winter Olympics          62         JAM  Bobsleigh
# 316090  2022 Winter Olympics          62         UKR  Bobsleigh
#
#                   event  result_id                     athlete  athlete_id  \
# 0       100 metres, Men      56265             Ernest Hutcheon       64710
# 1       400 metres, Men      56313                Henry Murray       64756
# 2       800 metres, Men      56338               Harvey Sutton       64808
# 3       800 metres, Men      56338                 Guy Haskins      922519
# 4       800 metres, Men      56338                Joseph Lynch       64735
# ...                 ...        ...                         ...         ...
# 316086   Monobob, Women   19019671              Karlien Sleper      148662
# 316087   Monobob, Women   19019671          Viktória Čerňanská      138683
# 316088   Monobob, Women   19019671                  Kim Yu-Ran      137542
# 316089   Monobob, Women   19019671  Jazmine Fenlator-Victorian      128682
# 316090   Monobob, Women   19019671                Lidiya Hunko      149047
#
#               pos medal  isTeamSport weight height        born     sex  \
# 0             DNS    na        False     na     na  1889-06-17    Male
# 1             DNS    na        False     na     na  1886-01-14    Male
# 2       3 h8 r1/2    na        False     na     na  1882-02-18    Male
# 3             DNS    na        False     na     na  1883-12-23    Male
# 4             DNS    na        False     na     na  1878-04-22    Male
# ...           ...   ...          ...    ...    ...         ...     ...
# 316086         16    na        False     na     na  1993-01-11  Female
# 316087         17    na        False     76  175.0  2002-03-29  Female
# 316088         18    na        False     78  170.0  1992-04-23  Female
# 316089         19    na        False  75-78  175.0  1985-08-29  Female
# 316090         20    na        False     na     na  1993-08-10  Female
#
#                   country  year     city
# 0             Australasia  1908   London
# 1             Australasia  1908   London
# 2             Australasia  1908   London
# 3             Australasia  1908   London
# 4             Australasia  1908   London
# ...                   ...   ...      ...
# 316086        Netherlands  2022  Beijing
# 316087           Slovakia  2022  Beijing
# 316088  Republic of Korea  2022  Beijing
# 316089            Jamaica  2022  Beijing
# 316090            Ukraine  2022  Beijing
#
# [194719 rows x 18 columns]

# %% [markdown]
# - Remove results that don't have a medal

# %%
dataset = dataset[dataset['medal'] != 'na']
dataset
# Out:
#                      edition  edition_id country_noc          sport  \
# 20      1908 Summer Olympics           5         ANZ      Athletics
# 30      1908 Summer Olympics           5         ANZ         Boxing
# 70      1908 Summer Olympics           5         ANZ       Swimming
# 75      1908 Summer Olympics           5         ANZ       Swimming
# 108     1912 Summer Olympics           6         ANZ       Swimming
# ...                      ...         ...         ...            ...
# 316060  2022 Winter Olympics          62         USA  Speed Skating
# 316063  2022 Winter Olympics          62         USA  Speed Skating
# 316070  2022 Winter Olympics          62         USA      Bobsleigh
# 316071  2022 Winter Olympics          62         USA      Bobsleigh
# 316072  2022 Winter Olympics          62         CAN      Bobsleigh
#
#                               event  result_id              athlete  \
# 20      3,500 metres Race Walk, Men      56421           Harry Kerr
# 30                Middleweight, Men      21263          Snowy Baker
# 70        400 metres Freestyle, Men       4494    Frank Beaurepaire
# 75      1,500 metres Freestyle, Men       4509    Frank Beaurepaire
# 108       100 metres Freestyle, Men       4554          Cecil Healy
# ...                             ...        ...                  ...
# 316060            500 metres, Women   19020424         Erin Jackson
# 316063          1,000 metres, Women   19020425        Brittany Bowe
# 316070               Monobob, Women   19019671    Kaillie Humphries
# 316071               Monobob, Women   19019671  Elana Meyers Taylor
# 316072               Monobob, Women   19019671   Christine de Bruin
#
#         athlete_id pos   medal  isTeamSport weight height        born     sex  \
# 20           64719   3  Bronze        False     76  184.0  1879-01-28    Male
# 30           45153   2  Silver        False     na     na  1884-02-08    Male
# 70           45155   2  Silver        False     65  170.0  1891-05-13    Male
# 75           45155   3  Bronze        False     65  170.0  1891-05-13    Male
# 108          45217   2  Silver        False     na     na  1881-11-28    Male
# ...            ...  ..     ...          ...    ...    ...         ...     ...
# 316060      138378   1    Gold        False     61  163.0  1992-09-19  Female
# 316063      128778   3  Bronze        False     66  170.0  1988-02-24  Female
# 316070      118672   1    Gold        False     77  170.0  1985-09-04  Female
# 316071      118644   2  Silver        False  79-82  170.0  1984-10-10  Female
# 316072      136825   3  Bronze        False     78  170.0  1989-03-03  Female
#
#               country  year       city
# 20        Australasia  1908     London
# 30        Australasia  1908     London
# 70        Australasia  1908     London
# 75        Australasia  1908     London
# 108       Australasia  1912  Stockholm
# ...               ...   ...        ...
# 316060  United States  2022    Beijing
# 316063  United States  2022    Beijing
# 316070  United States  2022    Beijing
# 316071  United States  2022    Beijing
# 316072         Canada  2022    Beijing
#
# [15356 rows x 18 columns]

# %% [markdown]
# - Remove columns

# %%
dataset = dataset.drop(columns=['edition_id', 'result_id', 'athlete_id', 'pos', 'isTeamSport'])
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 30      1908 Summer Olympics         ANZ         Boxing
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 108     1912 Summer Olympics         ANZ       Swimming
# ...                      ...         ...            ...
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316071  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                               event              athlete   medal weight  \
# 20      3,500 metres Race Walk, Men           Harry Kerr  Bronze     76
# 30                Middleweight, Men          Snowy Baker  Silver     na
# 70        400 metres Freestyle, Men    Frank Beaurepaire  Silver     65
# 75      1,500 metres Freestyle, Men    Frank Beaurepaire  Bronze     65
# 108       100 metres Freestyle, Men          Cecil Healy  Silver     na
# ...                             ...                  ...     ...    ...
# 316060            500 metres, Women         Erin Jackson    Gold     61
# 316063          1,000 metres, Women        Brittany Bowe  Bronze     66
# 316070               Monobob, Women    Kaillie Humphries    Gold     77
# 316071               Monobob, Women  Elana Meyers Taylor  Silver  79-82
# 316072               Monobob, Women   Christine de Bruin  Bronze     78
#
#        height        born     sex        country  year       city
# 20      184.0  1879-01-28    Male    Australasia  1908     London
# 30         na  1884-02-08    Male    Australasia  1908     London
# 70      170.0  1891-05-13    Male    Australasia  1908     London
# 75      170.0  1891-05-13    Male    Australasia  1908     London
# 108        na  1881-11-28    Male    Australasia  1912  Stockholm
# ...       ...         ...     ...            ...   ...        ...
# 316060  163.0  1992-09-19  Female  United States  2022    Beijing
# 316063  170.0  1988-02-24  Female  United States  2022    Beijing
# 316070  170.0  1985-09-04  Female  United States  2022    Beijing
# 316071  170.0  1984-10-10  Female  United States  2022    Beijing
# 316072  170.0  1989-03-03  Female         Canada  2022    Beijing
#
# [15356 rows x 13 columns]

# %% [markdown]
# - Convert height and weight to numeric value

# %%
dataset.loc[:, 'height'] = pd.to_numeric(dataset['height'], errors='coerce')
dataset.loc[:, 'weight'] = pd.to_numeric(dataset['weight'], errors='coerce')
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 30      1908 Summer Olympics         ANZ         Boxing
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 108     1912 Summer Olympics         ANZ       Swimming
# ...                      ...         ...            ...
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316071  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                               event              athlete   medal weight  \
# 20      3,500 metres Race Walk, Men           Harry Kerr  Bronze   76.0
# 30                Middleweight, Men          Snowy Baker  Silver    NaN
# 70        400 metres Freestyle, Men    Frank Beaurepaire  Silver   65.0
# 75      1,500 metres Freestyle, Men    Frank Beaurepaire  Bronze   65.0
# 108       100 metres Freestyle, Men          Cecil Healy  Silver    NaN
# ...                             ...                  ...     ...    ...
# 316060            500 metres, Women         Erin Jackson    Gold   61.0
# 316063          1,000 metres, Women        Brittany Bowe  Bronze   66.0
# 316070               Monobob, Women    Kaillie Humphries    Gold   77.0
# 316071               Monobob, Women  Elana Meyers Taylor  Silver    NaN
# 316072               Monobob, Women   Christine de Bruin  Bronze   78.0
#
#        height        born     sex        country  year       city
# 20      184.0  1879-01-28    Male    Australasia  1908     London
# 30        NaN  1884-02-08    Male    Australasia  1908     London
# 70      170.0  1891-05-13    Male    Australasia  1908     London
# 75      170.0  1891-05-13    Male    Australasia  1908     London
# 108       NaN  1881-11-28    Male    Australasia  1912  Stockholm
# ...       ...         ...     ...            ...   ...        ...
# 316060  163.0  1992-09-19  Female  United States  2022    Beijing
# 316063  170.0  1988-02-24  Female  United States  2022    Beijing
# 316070  170.0  1985-09-04  Female  United States  2022    Beijing
# 316071  170.0  1984-10-10  Female  United States  2022    Beijing
# 316072  170.0  1989-03-03  Female         Canada  2022    Beijing
#
# [15356 rows x 13 columns]

# %% [markdown]
# - Convert born to date value

# %%
dataset['born'] = pd.to_datetime(dataset['born'], errors='coerce')
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 30      1908 Summer Olympics         ANZ         Boxing
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 108     1912 Summer Olympics         ANZ       Swimming
# ...                      ...         ...            ...
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316071  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                               event              athlete   medal weight  \
# 20      3,500 metres Race Walk, Men           Harry Kerr  Bronze   76.0
# 30                Middleweight, Men          Snowy Baker  Silver    NaN
# 70        400 metres Freestyle, Men    Frank Beaurepaire  Silver   65.0
# 75      1,500 metres Freestyle, Men    Frank Beaurepaire  Bronze   65.0
# 108       100 metres Freestyle, Men          Cecil Healy  Silver    NaN
# ...                             ...                  ...     ...    ...
# 316060            500 metres, Women         Erin Jackson    Gold   61.0
# 316063          1,000 metres, Women        Brittany Bowe  Bronze   66.0
# 316070               Monobob, Women    Kaillie Humphries    Gold   77.0
# 316071               Monobob, Women  Elana Meyers Taylor  Silver    NaN
# 316072               Monobob, Women   Christine de Bruin  Bronze   78.0
#
#        height       born     sex        country  year       city
# 20      184.0 1879-01-28    Male    Australasia  1908     London
# 30        NaN 1884-02-08    Male    Australasia  1908     London
# 70      170.0 1891-05-13    Male    Australasia  1908     London
# 75      170.0 1891-05-13    Male    Australasia  1908     London
# 108       NaN 1881-11-28    Male    Australasia  1912  Stockholm
# ...       ...        ...     ...            ...   ...        ...
# 316060  163.0 1992-09-19  Female  United States  2022    Beijing
# 316063  170.0 1988-02-24  Female  United States  2022    Beijing
# 316070  170.0 1985-09-04  Female  United States  2022    Beijing
# 316071  170.0 1984-10-10  Female  United States  2022    Beijing
# 316072  170.0 1989-03-03  Female         Canada  2022    Beijing
#
# [15356 rows x 13 columns]

# %% [markdown]
# - Calculate `bmi` and add this to a new column

# %%
dataset.loc[:, 'bmi'] = pd.to_numeric(dataset['weight'] / ((dataset['height'] / 100) ** 2))
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 30      1908 Summer Olympics         ANZ         Boxing
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 108     1912 Summer Olympics         ANZ       Swimming
# ...                      ...         ...            ...
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316071  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                               event              athlete   medal weight  \
# 20      3,500 metres Race Walk, Men           Harry Kerr  Bronze   76.0
# 30                Middleweight, Men          Snowy Baker  Silver    NaN
# 70        400 metres Freestyle, Men    Frank Beaurepaire  Silver   65.0
# 75      1,500 metres Freestyle, Men    Frank Beaurepaire  Bronze   65.0
# 108       100 metres Freestyle, Men          Cecil Healy  Silver    NaN
# ...                             ...                  ...     ...    ...
# 316060            500 metres, Women         Erin Jackson    Gold   61.0
# 316063          1,000 metres, Women        Brittany Bowe  Bronze   66.0
# 316070               Monobob, Women    Kaillie Humphries    Gold   77.0
# 316071               Monobob, Women  Elana Meyers Taylor  Silver    NaN
# 316072               Monobob, Women   Christine de Bruin  Bronze   78.0
#
#        height       born     sex        country  year       city        bmi
# 20      184.0 1879-01-28    Male    Australasia  1908     London  22.448015
# 30        NaN 1884-02-08    Male    Australasia  1908     London        NaN
# 70      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 75      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 108       NaN 1881-11-28    Male    Australasia  1912  Stockholm        NaN
# ...       ...        ...     ...            ...   ...        ...        ...
# 316060  163.0 1992-09-19  Female  United States  2022    Beijing  22.959088
# 316063  170.0 1988-02-24  Female  United States  2022    Beijing  22.837370
# 316070  170.0 1985-09-04  Female  United States  2022    Beijing  26.643599
# 316071  170.0 1984-10-10  Female  United States  2022    Beijing        NaN
# 316072  170.0 1989-03-03  Female         Canada  2022    Beijing  26.989619
#
# [15356 rows x 14 columns]

# %% [markdown]
# - Calculate `age` and add this to new column

# %%
dataset['age'] = dataset['year'] - dataset['born'].dt.year
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 30      1908 Summer Olympics         ANZ         Boxing
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 108     1912 Summer Olympics         ANZ       Swimming
# ...                      ...         ...            ...
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316071  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                               event              athlete   medal weight  \
# 20      3,500 metres Race Walk, Men           Harry Kerr  Bronze   76.0
# 30                Middleweight, Men          Snowy Baker  Silver    NaN
# 70        400 metres Freestyle, Men    Frank Beaurepaire  Silver   65.0
# 75      1,500 metres Freestyle, Men    Frank Beaurepaire  Bronze   65.0
# 108       100 metres Freestyle, Men          Cecil Healy  Silver    NaN
# ...                             ...                  ...     ...    ...
# 316060            500 metres, Women         Erin Jackson    Gold   61.0
# 316063          1,000 metres, Women        Brittany Bowe  Bronze   66.0
# 316070               Monobob, Women    Kaillie Humphries    Gold   77.0
# 316071               Monobob, Women  Elana Meyers Taylor  Silver    NaN
# 316072               Monobob, Women   Christine de Bruin  Bronze   78.0
#
#        height       born     sex        country  year       city        bmi  \
# 20      184.0 1879-01-28    Male    Australasia  1908     London  22.448015
# 30        NaN 1884-02-08    Male    Australasia  1908     London        NaN
# 70      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 75      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 108       NaN 1881-11-28    Male    Australasia  1912  Stockholm        NaN
# ...       ...        ...     ...            ...   ...        ...        ...
# 316060  163.0 1992-09-19  Female  United States  2022    Beijing  22.959088
# 316063  170.0 1988-02-24  Female  United States  2022    Beijing  22.837370
# 316070  170.0 1985-09-04  Female  United States  2022    Beijing  26.643599
# 316071  170.0 1984-10-10  Female  United States  2022    Beijing        NaN
# 316072  170.0 1989-03-03  Female         Canada  2022    Beijing  26.989619
#
#          age
# 20      29.0
# 30      24.0
# 70      17.0
# 75      17.0
# 108     31.0
# ...      ...
# 316060  30.0
# 316063  34.0
# 316070  37.0
# 316071  38.0
# 316072  33.0
#
# [15356 rows x 15 columns]

# %% [markdown]
# - Clear records with `NaN` for `bmi`

# %%
dataset.dropna(subset=['bmi'], inplace=True)
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 130     1912 Summer Olympics         ANZ         Tennis
# 797     2012 Summer Olympics         BRN      Athletics
# ...                      ...         ...            ...
# 316033  2022 Winter Olympics         USA   Snowboarding
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                                event             athlete   medal weight  \
# 20       3,500 metres Race Walk, Men          Harry Kerr  Bronze   76.0
# 70         400 metres Freestyle, Men   Frank Beaurepaire  Silver   65.0
# 75       1,500 metres Freestyle, Men   Frank Beaurepaire  Bronze   65.0
# 130     Singles, Covered Courts, Men        Tony Wilding  Bronze   84.0
# 797              1,500 metres, Women        Maryam Jamal    Gold   61.0
# ...                              ...                 ...     ...    ...
# 316033           Boardercross, Women  Lindsey Jacobellis    Gold   64.0
# 316060             500 metres, Women        Erin Jackson    Gold   61.0
# 316063           1,000 metres, Women       Brittany Bowe  Bronze   66.0
# 316070                Monobob, Women   Kaillie Humphries    Gold   77.0
# 316072                Monobob, Women  Christine de Bruin  Bronze   78.0
#
#        height       born     sex        country  year       city        bmi  \
# 20      184.0 1879-01-28    Male    Australasia  1908     London  22.448015
# 70      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 75      170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 130     188.0 1883-10-31    Male    Australasia  1912  Stockholm  23.766410
# 797     170.0 1984-09-16  Female        Bahrain  2012     London  21.107266
# ...       ...        ...     ...            ...   ...        ...        ...
# 316033  168.0 1985-08-19  Female  United States  2022    Beijing  22.675737
# 316060  163.0 1992-09-19  Female  United States  2022    Beijing  22.959088
# 316063  170.0 1988-02-24  Female  United States  2022    Beijing  22.837370
# 316070  170.0 1985-09-04  Female  United States  2022    Beijing  26.643599
# 316072  170.0 1989-03-03  Female         Canada  2022    Beijing  26.989619
#
#          age
# 20      29.0
# 70      17.0
# 75      17.0
# 130     29.0
# 797     28.0
# ...      ...
# 316033  37.0
# 316060  30.0
# 316063  34.0
# 316070  37.0
# 316072  33.0
#
# [11862 rows x 15 columns]

# %% [markdown]
# - Change weight and height to numeric

# %%
dataset['height'] = pd.to_numeric(dataset['height'])
dataset['weight'] = pd.to_numeric(dataset['weight'])
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 130     1912 Summer Olympics         ANZ         Tennis
# 797     2012 Summer Olympics         BRN      Athletics
# ...                      ...         ...            ...
# 316033  2022 Winter Olympics         USA   Snowboarding
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                                event             athlete   medal  weight  \
# 20       3,500 metres Race Walk, Men          Harry Kerr  Bronze    76.0
# 70         400 metres Freestyle, Men   Frank Beaurepaire  Silver    65.0
# 75       1,500 metres Freestyle, Men   Frank Beaurepaire  Bronze    65.0
# 130     Singles, Covered Courts, Men        Tony Wilding  Bronze    84.0
# 797              1,500 metres, Women        Maryam Jamal    Gold    61.0
# ...                              ...                 ...     ...     ...
# 316033           Boardercross, Women  Lindsey Jacobellis    Gold    64.0
# 316060             500 metres, Women        Erin Jackson    Gold    61.0
# 316063           1,000 metres, Women       Brittany Bowe  Bronze    66.0
# 316070                Monobob, Women   Kaillie Humphries    Gold    77.0
# 316072                Monobob, Women  Christine de Bruin  Bronze    78.0
#
#         height       born     sex        country  year       city        bmi  \
# 20       184.0 1879-01-28    Male    Australasia  1908     London  22.448015
# 70       170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 75       170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 130      188.0 1883-10-31    Male    Australasia  1912  Stockholm  23.766410
# 797      170.0 1984-09-16  Female        Bahrain  2012     London  21.107266
# ...        ...        ...     ...            ...   ...        ...        ...
# 316033   168.0 1985-08-19  Female  United States  2022    Beijing  22.675737
# 316060   163.0 1992-09-19  Female  United States  2022    Beijing  22.959088
# 316063   170.0 1988-02-24  Female  United States  2022    Beijing  22.837370
# 316070   170.0 1985-09-04  Female  United States  2022    Beijing  26.643599
# 316072   170.0 1989-03-03  Female         Canada  2022    Beijing  26.989619
#
#          age
# 20      29.0
# 70      17.0
# 75      17.0
# 130     29.0
# 797     28.0
# ...      ...
# 316033  37.0
# 316060  30.0
# 316063  34.0
# 316070  37.0
# 316072  33.0
#
# [11862 rows x 15 columns]

# %% [markdown]
# ## Final dataset

# %%
dataset
# Out:
#                      edition country_noc          sport  \
# 20      1908 Summer Olympics         ANZ      Athletics
# 70      1908 Summer Olympics         ANZ       Swimming
# 75      1908 Summer Olympics         ANZ       Swimming
# 130     1912 Summer Olympics         ANZ         Tennis
# 797     2012 Summer Olympics         BRN      Athletics
# ...                      ...         ...            ...
# 316033  2022 Winter Olympics         USA   Snowboarding
# 316060  2022 Winter Olympics         USA  Speed Skating
# 316063  2022 Winter Olympics         USA  Speed Skating
# 316070  2022 Winter Olympics         USA      Bobsleigh
# 316072  2022 Winter Olympics         CAN      Bobsleigh
#
#                                event             athlete   medal  weight  \
# 20       3,500 metres Race Walk, Men          Harry Kerr  Bronze    76.0
# 70         400 metres Freestyle, Men   Frank Beaurepaire  Silver    65.0
# 75       1,500 metres Freestyle, Men   Frank Beaurepaire  Bronze    65.0
# 130     Singles, Covered Courts, Men        Tony Wilding  Bronze    84.0
# 797              1,500 metres, Women        Maryam Jamal    Gold    61.0
# ...                              ...                 ...     ...     ...
# 316033           Boardercross, Women  Lindsey Jacobellis    Gold    64.0
# 316060             500 metres, Women        Erin Jackson    Gold    61.0
# 316063           1,000 metres, Women       Brittany Bowe  Bronze    66.0
# 316070                Monobob, Women   Kaillie Humphries    Gold    77.0
# 316072                Monobob, Women  Christine de Bruin  Bronze    78.0
#
#         height       born     sex        country  year       city        bmi  \
# 20       184.0 1879-01-28    Male    Australasia  1908     London  22.448015
# 70       170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 75       170.0 1891-05-13    Male    Australasia  1908     London  22.491349
# 130      188.0 1883-10-31    Male    Australasia  1912  Stockholm  23.766410
# 797      170.0 1984-09-16  Female        Bahrain  2012     London  21.107266
# ...        ...        ...     ...            ...   ...        ...        ...
# 316033   168.0 1985-08-19  Female  United States  2022    Beijing  22.675737
# 316060   163.0 1992-09-19  Female  United States  2022    Beijing  22.959088
# 316063   170.0 1988-02-24  Female  United States  2022    Beijing  22.837370
# 316070   170.0 1985-09-04  Female  United States  2022    Beijing  26.643599
# 316072   170.0 1989-03-03  Female         Canada  2022    Beijing  26.989619
#
#          age
# 20      29.0
# 70      17.0
# 75      17.0
# 130     29.0
# 797     28.0
# ...      ...
# 316033  37.0
# 316060  30.0
# 316063  34.0
# 316070  37.0
# 316072  33.0
#
# [11862 rows x 15 columns]

# %% [markdown]
# ## Correlation

# %%
dataset.corr(numeric_only=True)
# Out:
#           weight    height      year       bmi       age
# weight  1.000000  0.745603 -0.044645  0.871106  0.163130
# height  0.745603  1.000000 -0.049056  0.333994  0.089555
# year   -0.044645 -0.049056  1.000000 -0.035036  0.122464
# bmi     0.871106  0.333994 -0.035036  1.000000  0.178236
# age     0.163130  0.089555  0.122464  0.178236  1.000000

# %% [markdown]
# ## Graphs

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### BMI distribution

# %%
import math as math

# This code is in comments to more easily compare with the Z-indexed values.
# Uncomment to a get different view, where you only see 'nomal range' BMIs. This gives a better look at the distribution for the average athlete.

# minBmi = math.floor(dataset['bmi'].min())
# maxBmi = 35 # not math.ceil(dataset['bmi'].max()) as it goes up to 55 and is not relevant to display the thing we want to actually show ...
# bins = list(range(minBmi, maxBmi))

dataset['bmi'].plot(kind = 'hist', bins = 20)
# plt.xticks(bins)

plt.title('BMI Distribution')
plt.xlabel("BMI Index")
plt.show()

# %% [markdown]
# ### BMI distribution (Z-Indexed)

# %%
# pip install -U scikit-learn
from sklearn.preprocessing import StandardScaler
import math as math

bmi_z = StandardScaler().fit_transform(dataset[['bmi']]);
bmi_z = pd.DataFrame(bmi_z, columns = ['bmi'])

bmi_z.plot(kind = 'hist', bins = 20)
plt.title('BMI Distribution (Z-Indexed)')
plt.xlabel("BMI Index (Z-Indexed)")
# Out:
# Text(0.5, 0, 'BMI Index (Z-Indexed)')

# %% [markdown]
# ### Age vs BMI

# %%
dataset.plot(x='age', y='bmi', kind='scatter')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI')
plt.show()

# %%
dataset.plot(x='age', y='bmi', kind='line')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI')
plt.show()

# %%
dataset.plot(x='age', y='bmi', kind='bar')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI')
plt.show()

# %%
dataset.plot(x='age', y='bmi', kind='area')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Age vs BMI')
plt.show()

# %% [markdown]
# ### BMI vs Weight

# %%
dataset.plot(x='weight', y='bmi', kind='scatter')
plt.xlabel('Weight')
plt.ylabel('BMI')
plt.title('Weight vs BMI')
plt.show()

# %%
dataset.plot(x='weight', y='bmi', kind='line')
plt.xlabel('Weight')
plt.ylabel('BMI')
plt.title('Weight vs BMI')
plt.show()

# %%
dataset.plot(x='weight', y='bmi', kind='bar')
plt.xlabel('Weight')
plt.ylabel('BMI')
plt.title('Weight vs BMI')
plt.show()

# %% [markdown]
# dataset.plot(x='weight', y='bmi', kind='area')
# plt.xlabel('Weight')
# plt.ylabel('BMI')
# plt.title('Weight vs BMI')
# plt.show()
