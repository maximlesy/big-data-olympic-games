# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Countries

# %%
import pandas as pd
countries = pd.read_csv("../dataset/Olympics_Country.csv")
countries
# Out:
#     country_noc                    country
# 0           AFG                Afghanistan
# 1           ALB                    Albania
# 2           ALG                    Algeria
# 3           ASA             American Samoa
# 4           AND                    Andorra
# ..          ...                        ...
# 229         YEM                      Yemen
# 230         YUG                 Yugoslavia
# 231         ZAM                     Zambia
# 232         ZIM                   Zimbabwe
# 233         ROC  Russian Olympic Committee
#
# [234 rows x 2 columns]

# %%
print(countries.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country_noc  234 non-null    object
#  1   country      234 non-null    object
# dtypes: object(2)
# memory usage: 3.8+ KB
# None

# %% [markdown]
# ## Games
# ### Games

# %%
games = pd.read_csv("../dataset/Olympics_Games.csv")
games
# Out:
#                  edition  edition_id   edition_url  year  \
# 0   1896 Summer Olympics           1   /editions/1  1896
# 1   1900 Summer Olympics           2   /editions/2  1900
# 2   1904 Summer Olympics           3   /editions/3  1904
# 3   1908 Summer Olympics           5   /editions/5  1908
# 4   1912 Summer Olympics           6   /editions/6  1912
# ..                   ...         ...           ...   ...
# 59  2018 Winter Olympics          60  /editions/60  2018
# 60  2022 Winter Olympics          62  /editions/62  2022
# 61  2026 Winter Olympics          72  /editions/72  2026
# 62       1956 Equestrian          48  /editions/48  1956
# 63     1906 Intercalated           4   /editions/4  1906
#
#                         city       country_flag_url country_noc   start_date  \
# 0                     Athina  /images/flags/GRE.png         GRE      6 April
# 1                      Paris  /images/flags/FRA.png         FRA          NaN
# 2                  St. Louis  /images/flags/USA.png         USA       14 May
# 3                     London  /images/flags/GBR.png         GBR      13 July
# 4                  Stockholm  /images/flags/SWE.png         SWE       6 July
# ..                       ...                    ...         ...          ...
# 59               PyeongChang  /images/flags/KOR.png         KOR   9 February
# 60                   Beijing  /images/flags/CHN.png         CHN   4 February
# 61  Milano-Cortina d'Ampezzo  /images/flags/ITA.png         ITA   6 February
# 62                 Stockholm  /images/flags/SWE.png         SWE      10 June
# 63                    Athina  /images/flags/GRE.png         GRE     22 April
#
#        end_date       competition_date isHeld
# 0      15 April           6 – 13 April    NaN
# 1           NaN    14 May – 28 October    NaN
# 2           NaN   1 July – 26 November    NaN
# 3           NaN  27 April – 31 October    NaN
# 4       27 July        5 May – 27 July    NaN
# ..          ...                    ...    ...
# 59  25 February        8 – 25 February    NaN
# 60  20 February        2 – 20 February    NaN
# 61  22 February        4 – 22 February    NaN
# 62      17 June           11 – 17 June    NaN
# 63        2 May      22 April –  2 May    NaN
#
# [64 rows x 11 columns]

# %%
print(games.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   edition           64 non-null     object
#  1   edition_id        64 non-null     int64
#  2   edition_url       64 non-null     object
#  3   year              64 non-null     int64
#  4   city              64 non-null     object
#  5   country_flag_url  64 non-null     object
#  6   country_noc       64 non-null     object
#  7   start_date        55 non-null     object
#  8   end_date          53 non-null     object
#  9   competition_date  64 non-null     object
#  10  isHeld            5 non-null      object
# dtypes: int64(2), object(9)
# memory usage: 5.6+ KB
# None

# %% [markdown]
# #### `isHeld` exploration

# %%
nan_count = games['isHeld'].isna().sum()
print("Number of NaN's: " + str(nan_count))

not_nan_count = len(games) - nan_count
print("Number of no NaN's: " + str(not_nan_count))
# Out:
# Number of NaN's: 59
# Number of no NaN's: 5

# %% [markdown]
# ### Games Medal Tally

# %%
gamesMedalTally = pd.read_csv("../dataset/Olympic_Games_Medal_Tally.csv")
gamesMedalTally
# Out:
#                    edition  edition_id  year        country country_noc  gold  \
# 0     1896 Summer Olympics           1  1896  United States         USA    11
# 1     1896 Summer Olympics           1  1896         Greece         GRE    10
# 2     1896 Summer Olympics           1  1896        Germany         GER     6
# 3     1896 Summer Olympics           1  1896         France         FRA     5
# 4     1896 Summer Olympics           1  1896  Great Britain         GBR     2
# ...                    ...         ...   ...            ...         ...   ...
# 1802     1906 Intercalated           4  1906         Canada         CAN     1
# 1803     1906 Intercalated           4  1906         Norway         NOR     1
# 1804     1906 Intercalated           4  1906    Netherlands         NED     0
# 1805     1906 Intercalated           4  1906      Australia         AUS     0
# 1806     1906 Intercalated           4  1906        Bohemia         BOH     0
#
#       silver  bronze  total
# 0          7       2     20
# 1         18      19     47
# 2          5       2     13
# 3          4       2     11
# 4          3       2      7
# ...      ...     ...    ...
# 1802       1       0      2
# 1803       1       0      2
# 1804       1       2      3
# 1805       0       3      3
# 1806       0       2      2
#
# [1807 rows x 9 columns]

# %%
print(gamesMedalTally.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1807 entries, 0 to 1806
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   edition      1807 non-null   object
#  1   edition_id   1807 non-null   int64
#  2   year         1807 non-null   int64
#  3   country      1807 non-null   object
#  4   country_noc  1807 non-null   object
#  5   gold         1807 non-null   int64
#  6   silver       1807 non-null   int64
#  7   bronze       1807 non-null   int64
#  8   total        1807 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 127.2+ KB
# None

# %% [markdown]
# ## Athletes
# ### Athlete Bio

# %%
athletes = pd.read_csv("../dataset/Olympic_Athlete_Bio.csv")
athletesSource = athletes

# %%
print(athletes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155031 entries, 0 to 155030
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     155031 non-null  int64
#  1   name           155031 non-null  object
#  2   sex            155031 non-null  object
#  3   born           155031 non-null  object
#  4   height         155031 non-null  object
#  5   weight         155031 non-null  object
#  6   country        155031 non-null  object
#  7   country_noc    155031 non-null  object
#  8   description    155031 non-null  object
#  9   special_notes  155031 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 11.8+ MB
# None

# %% [markdown]
# #### Height and weight checks and validations for BMI calculation

# %% [markdown]
# - Weight == na

# %%
naWeightAthletes = athletes[(athletes['weight'] == 'na')]
naWeightAthletes
# Out:
#         athlete_id                        name     sex        born height  \
# 0            16809              Károly Teppert    Male  1891-07-20     na
# 6            24791                 Saad Rashed    Male  1928-11-20     na
# 9            74076            Hassan Illiassou    Male  1966-09-22     na
# 12           35720               Achille Mengé    Male          na     na
# 14          142137      Nanna Skodborg Merrald  Female  1993-10-08     na
# ...            ...                         ...     ...         ...    ...
# 155013       19515               Jo Myeong-Jun    Male  1970-07-29     na
# 155014       25572      Ioannis Andrianopoulos    Male  1900-01-01     na
# 155018       51182             Frances Schroth  Female  1893-04-11     na
# 155019      146786         Gabriel Gerald Geay    Male  1996-09-10     na
# 155027      701697  Hendrik Mangelaar Meertens    Male  1908-09-30     na
#
#        weight                                         country country_noc  \
# 0          na                                         Hungary         HUN
# 6          na                                           Egypt         EGY
# 9          na                                           Niger         NIG
# 12         na                                         Belgium         BEL
# 14         na                                         Denmark         DEN
# ...       ...                                             ...         ...
# 155013     na   People's Republic of China  Republic of Korea         CHN
# 155014     na                                          Greece         GRE
# 155018     na                                   United States         USA
# 155019     na                     United Republic of Tanzania         TAN
# 155027     na                                     Netherlands         NED
#
#                                               description  \
# 0       Károly Teppert started competing in cycling in...
# 6                                                      na
# 9                       Personal Best: 100 – 10.3 (1994).
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013                                                 na
# 155014                                                 na
# 155018  Mrs. Frances Schroth, from Oakland, California...
# 155019                                                 na
# 155027  Hendrik Mangelaar Meertens, usually known as “...
#
#                                             special_notes
# 0                                                      na
# 6       Listed in Olympians Who Won a Medal at the Med...
# 9                                                      na
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013  Listed in Olympians Who Won a Medal at the Asi...
# 155014                 Brother of Georgios Andrianopoulos
# 155018  Wife of George Schroth Listed in Olympians Who...
# 155019                                                 na
# 155027  Listed in Olympians Who Were Killed or Missing...
#
# [50547 rows x 10 columns]

# %% [markdown]
# - Height == na

# %%
naHeightAthletes = athletes[(athletes['height'] == 'na')]
naHeightAthletes
# Out:
#         athlete_id                        name     sex        born height  \
# 0            16809              Károly Teppert    Male  1891-07-20     na
# 6            24791                 Saad Rashed    Male  1928-11-20     na
# 9            74076            Hassan Illiassou    Male  1966-09-22     na
# 12           35720               Achille Mengé    Male          na     na
# 14          142137      Nanna Skodborg Merrald  Female  1993-10-08     na
# ...            ...                         ...     ...         ...    ...
# 155013       19515               Jo Myeong-Jun    Male  1970-07-29     na
# 155014       25572      Ioannis Andrianopoulos    Male  1900-01-01     na
# 155018       51182             Frances Schroth  Female  1893-04-11     na
# 155019      146786         Gabriel Gerald Geay    Male  1996-09-10     na
# 155027      701697  Hendrik Mangelaar Meertens    Male  1908-09-30     na
#
#        weight                                         country country_noc  \
# 0          na                                         Hungary         HUN
# 6          na                                           Egypt         EGY
# 9          na                                           Niger         NIG
# 12         na                                         Belgium         BEL
# 14         na                                         Denmark         DEN
# ...       ...                                             ...         ...
# 155013     na   People's Republic of China  Republic of Korea         CHN
# 155014     na                                          Greece         GRE
# 155018     na                                   United States         USA
# 155019     na                     United Republic of Tanzania         TAN
# 155027     na                                     Netherlands         NED
#
#                                               description  \
# 0       Károly Teppert started competing in cycling in...
# 6                                                      na
# 9                       Personal Best: 100 – 10.3 (1994).
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013                                                 na
# 155014                                                 na
# 155018  Mrs. Frances Schroth, from Oakland, California...
# 155019                                                 na
# 155027  Hendrik Mangelaar Meertens, usually known as “...
#
#                                             special_notes
# 0                                                      na
# 6       Listed in Olympians Who Won a Medal at the Med...
# 9                                                      na
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013  Listed in Olympians Who Won a Medal at the Asi...
# 155014                 Brother of Georgios Andrianopoulos
# 155018  Wife of George Schroth Listed in Olympians Who...
# 155019                                                 na
# 155027  Listed in Olympians Who Were Killed or Missing...
#
# [50547 rows x 10 columns]

# %% [markdown]
# - Height == na AND Weight == na

# %%
naHeightAndWeigthAthletes = athletes[(athletes['height'] == 'na') & (athletes['weight'] == 'na')]
naHeightAndWeigthAthletes
# Out:
#         athlete_id                        name     sex        born height  \
# 0            16809              Károly Teppert    Male  1891-07-20     na
# 6            24791                 Saad Rashed    Male  1928-11-20     na
# 9            74076            Hassan Illiassou    Male  1966-09-22     na
# 12           35720               Achille Mengé    Male          na     na
# 14          142137      Nanna Skodborg Merrald  Female  1993-10-08     na
# ...            ...                         ...     ...         ...    ...
# 155013       19515               Jo Myeong-Jun    Male  1970-07-29     na
# 155014       25572      Ioannis Andrianopoulos    Male  1900-01-01     na
# 155018       51182             Frances Schroth  Female  1893-04-11     na
# 155019      146786         Gabriel Gerald Geay    Male  1996-09-10     na
# 155027      701697  Hendrik Mangelaar Meertens    Male  1908-09-30     na
#
#        weight                                         country country_noc  \
# 0          na                                         Hungary         HUN
# 6          na                                           Egypt         EGY
# 9          na                                           Niger         NIG
# 12         na                                         Belgium         BEL
# 14         na                                         Denmark         DEN
# ...       ...                                             ...         ...
# 155013     na   People's Republic of China  Republic of Korea         CHN
# 155014     na                                          Greece         GRE
# 155018     na                                   United States         USA
# 155019     na                     United Republic of Tanzania         TAN
# 155027     na                                     Netherlands         NED
#
#                                               description  \
# 0       Károly Teppert started competing in cycling in...
# 6                                                      na
# 9                       Personal Best: 100 – 10.3 (1994).
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013                                                 na
# 155014                                                 na
# 155018  Mrs. Frances Schroth, from Oakland, California...
# 155019                                                 na
# 155027  Hendrik Mangelaar Meertens, usually known as “...
#
#                                             special_notes
# 0                                                      na
# 6       Listed in Olympians Who Won a Medal at the Med...
# 9                                                      na
# 12                                                     na
# 14                                                     na
# ...                                                   ...
# 155013  Listed in Olympians Who Won a Medal at the Asi...
# 155014                 Brother of Georgios Andrianopoulos
# 155018  Wife of George Schroth Listed in Olympians Who...
# 155019                                                 na
# 155027  Listed in Olympians Who Were Killed or Missing...
#
# [50547 rows x 10 columns]

# %% [markdown]
# - Not all athletes have a numeric weight value

# %%
nonNaAthletes = athletes[(athletes['height'] != 'na') & (athletes['weight'] != 'na')]
nonNumericWeights = nonNaAthletes[~nonNaAthletes['weight'].str.isnumeric()]
nonNumericWeights
# Out:
#         athlete_id              name     sex        born height   weight  \
# 238         111977  Amandine Leynaud  Female  1986-05-02  178.0    64-69
# 243          55798      Helmut Losch    Male  1947-10-12  179.0  106-111
# 969          36773     Väinö Huhtala    Male  1934-06-23  181.0    80-82
# 990          92148   Pekka Marjamäki    Male  1947-12-18  186.0    88-96
# 994         131582  Darya Dmitriyeva  Female  1995-08-09  178.0    71-74
# ...            ...               ...     ...         ...    ...      ...
# 154451        2957   Kalevi Marjamaa    Male  1953-01-29  180.0    63-71
# 154481       17225  Sixten Wackström    Male  1960-08-02  180.0    76-77
# 154519       95363   Anssi Melametsä    Male  1961-06-21  183.0    85-88
# 154731       87275      Ensio Hyytiä    Male  1938-03-24  180.0    79-81
# 154871       87273     Erkki Hytönen    Male  1933-05-27  182.0    88-90
#
#                          country country_noc  \
# 238                       France         FRA
# 243                 East Germany         GDR
# 969                      Finland         FIN
# 990                      Finland         FIN
# 994      ROC  Russian Federation         ROC
# ...                          ...         ...
# 154451                   Finland         FIN
# 154481                   Finland         FIN
# 154519                   Finland         FIN
# 154731                   Finland         FIN
# 154871                   Finland         FIN
#
#                                               description  \
# 238                                                    na
# 243     Heavyweight lifter Helmut Losch finished fourt...
# 969                                                    na
# 990                                                    na
# 994                                                    na
# ...                                                   ...
# 154451                                                 na
# 154481  In addition to his two Olympics appearances in...
# 154519                                                 na
# 154731                                                 na
# 154871  A 1952 ice hockey Winter Olympian for Finland,...
#
#                                             special_notes
# 238                                                    na
# 243                                                    na
# 969                                                    na
# 990                                                    na
# 994                                                    na
# ...                                                   ...
# 154451       Brother-in-law of Helinä Laihorinne-Marjamaa
# 154481  Son of Ole Wackström Brother of Patrick Wackström
# 154519  Listed in Olympians Who Won a Medal at the Eur...
# 154731  Listed in Olympians Who Won a Medal at the Wor...
# 154871                                                 na
#
# [955 rows x 10 columns]

# %% [markdown]
# - Height value is not numeric, so convert it to numeric. If value contains non-numeric values, those will be converted to NaN

# %%
athletes['height'] = pd.to_numeric(athletes['height'], errors='coerce')

# %% [markdown]
# - Weight value is not numeric, so convert it to numeric. If value contains non-numeric values, those will be converted to NaN. There are some values like `55 - 57`, those will be changed to NaN.

# %%
athletes['weight'] = pd.to_numeric(athletes['weight'], errors='coerce')

# %% [markdown]
# - Remove all the records with `NaN` in height or weight

# %%
filteredAthletes = athletes.dropna(subset = ['weight', 'height'])
filteredAthletes
# Out:
#         athlete_id                 name     sex        born  height  weight  \
# 1            43737    Andrzej Socharski    Male  1947-08-31   173.0    72.0
# 2            50147  Nathalie Wunderlich  Female  1971-06-03   170.0    50.0
# 3             5085           Miha Lokar    Male  1935-09-10   182.0    76.0
# 4           136329          Austin Hack    Male  1992-05-17   203.0   100.0
# 5            38633     Tsuneo Ogasawara    Male  1942-07-30   181.0    80.0
# ...            ...                  ...     ...         ...     ...     ...
# 155025       74088       Oddrun Hokland  Female  1942-11-29   162.0    59.0
# 155026       25136         Jean Palluch    Male  1923-12-23   180.0    80.0
# 155028       11757        Jo Hyeong-Won    Male  1936-07-12   173.0    65.0
# 155029       21666          Raúl Maroto    Male  1965-09-05   190.0    76.0
# 155030       72486       Shizo Kanakuri    Male  1891-08-20   170.0    64.0
#
#                    country country_noc  \
# 1                   Poland         POL
# 2              Switzerland         SUI
# 3               Yugoslavia         YUG
# 4            United States         USA
# 5                    Japan         JPN
# ...                    ...         ...
# 155025              Norway         NOR
# 155026              France         FRA
# 155028   Republic of Korea         KOR
# 155029               Spain         ESP
# 155030               Japan         JPN
#
#                                               description  \
# 1                                                      na
# 2                                                      na
# 3                                                      na
# 4                                                      na
# 5                                                      na
# ...                                                   ...
# 155025  Personal Bests: LJ – 6.26 (1964); Pen – 4540 (...
# 155026                                                 na
# 155028                                                 na
# 155029                                                 na
# 155030  Kanakuri had a weak constitution as a child un...
#
#                                             special_notes
# 1       Listed in Olympians Who Won a Medal at the Wor...
# 2                                                      na
# 3       Listed in Olympians Who Won a Medal at the Eur...
# 4                                                      na
# 5                                                      na
# ...                                                   ...
# 155025                                                 na
# 155026                                                 na
# 155028                                                 na
# 155029  Listed in Olympians Who Won a Medal at the Med...
# 155030                                                 na
#
# [103529 rows x 10 columns]

# %% [markdown]
# #### Conclusions

# %%
print("There are " + str(len(athletesSource)) + " athletes")
print("There are " + str(len(naWeightAthletes)) + " athletes, with na as weight")
print("There are " + str(len(naHeightAthletes)) + " athletes, with na as height")
print("There are " + str(len(naHeightAndWeigthAthletes)) + " athletes, with na as height AND na as weight")
print("There are " + str(len(nonNumericWeights)) + " athletes with a non numeric value for their weight")
print("There are " + str(len(filteredAthletes)) + " athletes with a that can be used to calculate their BMI")
# Out:
# There are 155031 athletes
# There are 50547 athletes, with na as weight
# There are 50547 athletes, with na as height
# There are 50547 athletes, with na as height AND na as weight
# There are 955 athletes with a non numeric value for their weight
# There are 103529 athletes with a that can be used to calculate their BMI

# %% [markdown]
# ### Athlete Event Results

# %%
athleteEventResults = pd.read_csv("../dataset/Olympic_Athlete_Event_Results.csv")
athleteEventResults

# %%
print(athleteEventResults.info())

# %% [markdown]
# ## Results
# ### Results

# %%
results = pd.read_csv("../dataset/Olympic_Results.csv")
results

# %%
print(results.info())
